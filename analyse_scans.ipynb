# %%
import pandas as pd

# %%
PRIMARY_SCANS_DIR = "./out/amine_split/primary_scan"
SECONDARY_SCANS_DIR = "./out/amine_split/secondary_scan"
AROMATIC_SCANS_DIR = "./out/amine_split/aromatic_scan"

# %%
PRIMARY_DF = pd.read_csv(f"{PRIMARY_SCANS_DIR}/primary_aliphatic_amines.tsv", sep = "\t")
PRIMARY_DF.columns
# Out:
# Index(['Label', 'InputSMILES', 'CID', 'InChIKey', 'IUPACName', 'ResolveError',
#        'MentionCount', 'SourceType', 'Database', 'Query', 'MatchMode',
#        'Confidence', 'Title', 'Year', 'ReferenceID', 'URL',
#        'AuthorsOrAssignee', 'JournalOrPublication', 'Snippet'],
#       dtype='object')

# %%
PRIMARY_DF['Label'][1]
# Out:
# 'Chemistry 2545'

# %%
PRIMARY_DF['InputSMILES'][1]
# Out:
# 'NCC(C(=O)N1CCC2(CCCN(C(=O)c3ccc(C#Cc4ccccc4)cc3)C2)C1)c1ccccc1'

# %%
PRIMARY_DF['CID'][1]
# Out:
# np.float64(171705985.0)

# %%
PRIMARY_DF['InChIKey'][1]
# Out:
# 'XIBKZTUGHDYRSO-UHFFFAOYSA-N'

# %%
PRIMARY_DF['IUPACName'][1]
# Out:
# '3-amino-2-phenyl-1-[9-[4-(2-phenylethynyl)benzoyl]-2,9-diazaspiro[4.5]decan-2-yl]propan-1-one'

# %%
for col in PRIMARY_DF.columns: 
    print(PRIMARY_DF[col][1])
# Out:
# Chemistry 2545
# NCC(C(=O)N1CCC2(CCCN(C(=O)c3ccc(C#Cc4ccccc4)cc3)C2)C1)c1ccccc1
# 171705985.0
# XIBKZTUGHDYRSO-UHFFFAOYSA-N
# 3-amino-2-phenyl-1-[9-[4-(2-phenylethynyl)benzoyl]-2,9-diazaspiro[4.5]decan-2-yl]propan-1-one
# nan
# 0
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
